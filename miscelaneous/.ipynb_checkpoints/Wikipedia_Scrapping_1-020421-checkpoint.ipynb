# %% [markdown]
# # Web Scraping, data de exportaciones, importaciones , Producto Bruto , exportacion y produccion de oil.
#
# Alumno 1: Tatiana Piccolomini
#
# Alumno 2: Jonathan Zambrano

# %% [markdown]
# ## Paginas de las que tenemos que sacar la info y armar un dataframe . Para luego joinear todo y hacer un data frame q pasamos a csv
#
#      -https://en.wikipedia.org/wiki/List_of_countries_and_dependencies_by_population (LISTO)
#
#     -https://en.wikipedia.org/wiki/List_of_countries_by_exports
#
#     -https://en.wikipedia.org/wiki/List_of_countries_by_imports
#
#     -https://en.wikipedia.org/wiki/List_of_countries_by_leading_trade_partners
#
#     -https://en.wikipedia.org/wiki/List_of_countries_by_oil_exports
#
#     -https://en.wikipedia.org/wiki/List_of_countries_by_oil_production
#
#     -https://en.wikipedia.org/wiki/List_of_countries_by_net_oil_exports

# %%
import numpy as np
import pandas as pd

from urllib.request import urlopen
from bs4 import BeautifulSoup

# %% [markdown]
# ## Primer link https://en.wikipedia.org/wiki/List_of_countries_and_dependencies_by_population

# %%
#esta celda es para saber como encontrar la tabla en el html

content = getHTMLContent('https://en.wikipedia.org/wiki/List_of_countries_and_dependencies_by_population')
tables = content.find_all('table')
for table in tables:
    print(table.prettify())#miro las partes de la pagina con la etiqueta table
    # identifico como se llama la class para poder sacar esa informacion
# Out:
# <table class="wikitable sortable plainrowheaders" style="text-align:right">
#  <tbody>
#   <tr>
#    <th data-sort-type="number">
#     Rank
#    </th>
#    <th>
#     Country
#     <br/>
#     (or dependent territory)
#    </th>
#    <th>
#     Population
#    </th>
#    <th>
#     % of world
#    </th>
#    <th>
#     Date
#    </th>
#    <th>
#     Source
#     <br/>
#     (official or United Nations)
#    </th>
#   </tr>
#   <tr>
#    <th>
#     1
#    </th>
#    <td align="left">
#     <span class="flagicon">
# ...

# %%
#encontre que la etiqueta que necesito es wikitable sortable plainrowheaders

table = content.find('table', {'class': 'wikitable sortable plainrowheaders'})
rows = table.find_all('tr')

# %%
# Me armo el primer data frame con country y population del primer link

# %%
 
Data_1=pd.DataFrame(columns = ['Country','Population'])
rows_list=[]


# 
for row in rows:
    cells = row.find_all('td')
    if len(cells) > 1:
        country = cells[0].find('a').text
        population=cells[1].text
        proporcion=cells[2].text
        
        
        rows_list.append([country,population,proporcion])
Data_1=pd.DataFrame(rows_list,columns = ['Country','Population','Proporcion_mundial'])
Data_1['Population']=Data_1.apply(lambda x: comma_to_none(x['Population']),  axis=1)
Data_1
# Out:
#                                          Country  Population Proporcion_mundial
# 0                                          China  1407402560              17.9%
# 1                                          India  1375432838              17.5%
# 2                                  United States   331458869              4.22%
# 3                                      Indonesia   271350000              3.45%
# 4                                       Pakistan   225200000              2.87%
# 5                                         Brazil   212969523              2.71%
# 6                                        Nigeria   211401000              2.69%
# 7                                     Bangladesh   170453540              2.17%
# 8                                         Russia   146238185              1.86%
# 9                                         Mexico   126014024              1.60%
# 10                                         Japan   125480000              1.60%
# ...

# %%
#Agrego Palestina a mano parece q como to ma el link
Data_1['Country'][120]='Palestine'

# %%
Data_1
# Out:
#                                          Country  Population Proporcion_mundial
# 0                                          China  1407329960              17.9%
# 1                                          India  1375231543              17.5%
# 2                                  United States   331430647              4.22%
# 3                                      Indonesia   271350000              3.45%
# 4                                       Pakistan   225200000              2.87%
# 5                                         Brazil   212947458              2.71%
# 6                                        Nigeria   211401000              2.69%
# 7                                     Bangladesh   170425410              2.17%
# 8                                         Russia   146238185              1.86%
# 9                                         Mexico   126014024              1.60%
# 10                                         Japan   125480000              1.60%
# ...

# %%
# No trae palestina y saint AMrtin pero en el codigo html se ven igual que los demas
<a class="mw-redirect" href="/wiki/Demographics_of_Palestine" title="Demographics of Palestine">
      Palestine
     </a>
        
  </a>
      </span>
      <a href="/wiki/Collectivity_of_Saint_Martin" title="Collectivity of Saint Martin">
       Saint Martin
      </a>
     </span>
     (
     <a href="/wiki/France" title="France">
      France
        
<a href="/wiki/Demographics_of_Norway" title="Demographics of Norway">
     Norway
</a>

# %% [markdown]
# ### Country sera como la primary key por la cual uniremos este data set con lo siguientes para formar 1 solo data set

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
lista_paises=Data_1['Country'].tolist()

# %%
Posible data a incluir
Country(or dependent territory)
Population
# %of worldpopulation
Total Area
Percentage Water
Total Nominal GDP
Per Capita GDP

# %% [markdown]
# ## Segundo Link https://en.wikipedia.org/wiki/List_of_countries_by_exports

# %%
content2 = getHTMLContent('https://en.wikipedia.org/wiki/List_of_countries_by_exports')
tables2 = content2.find_all('table')
for table in tables2:
    print(table.prettify()) #esto es para ver el codigo html y encontrar las tablas que tiene la pagina
# Out:
# <table class="box-Update plainlinks metadata ambox ambox-content ambox-Update" role="presentation">
#  <tbody>
#   <tr>
#    <td class="mbox-image">
#     <div style="width:52px">
#      <img alt="Ambox current red.svg" data-file-height="290" data-file-width="360" decoding="async" height="34" src="//upload.wikimedia.org/wikipedia/commons/thumb/9/98/Ambox_current_red.svg/42px-Ambox_current_red.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/9/98/Ambox_current_red.svg/63px-Ambox_current_red.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/9/98/Ambox_current_red.svg/84px-Ambox_current_red.svg.png 2x" width="42"/>
#     </div>
#    </td>
#    <td class="mbox-text">
#     <div class="mbox-text-span">
#      This article needs to be
#      <b>
#       updated
#      </b>
#      .
#      <span class="hide-when-compact">
#       Please update this article to reflect recent events or newly available information.
#      </span>
#      <small class="date-container">
# ...

# %%
table class="wikitable sortable"
table class="wikitable"

# %%
#encuentro la tabal con exportaciones

# %%
rows2[3].find_all('td')[4]
# Out:
# <td>2019
# </td>

# %%
table2 = content2.find('table', {'class': 'wikitable sortable'})
rows2 = table2.find_all('tr')

Data_2=pd.DataFrame(columns = ['Country','export_million_USD','porcentaje_GDP','Year_exp_data'])
rows_list2=[]

for row in rows2:
    cells2 = row.find_all('td')
    if len(cells2) > 1:
        country= cells2[1].find('a').text
        export_million_USD=cells2[2].text
        porcentaje_GDP=cells2[3].text
        Year_exp_data=cells2[4].text[:-1]
        #print(porcentaje_GDP)
        rows_list2.append([country,export_million_USD,porcentaje_GDP,Year_exp_data])
Data_2=pd.DataFrame(rows_list2,columns = ['Country','export_million_USD','porcentaje_GDP','Year_exp_data'])
Data_2['export_million_USD']=Data_2.apply(lambda x: comma_to_none(x['export_million_USD']),  axis=1)
Data_2
# Out:
#                               Country export_million_USD porcentaje_GDP Year_exp_data
# 0                               China            2643376          11.8%          2019
# 1                       United States            2498032          11.7%          2019
# 2                             Germany            1810933          47.0%          2019
# 3                               Japan             904883          18.5%          2018
# 4                      United Kingdom             891875          31.5%          2019
# 5                              France             882761          31.8%          2019
# 6                         Netherlands             750172          82.5%          2019
# 7                         South Korea             669594          39.8%          2019
# 8                           Hong Kong             648982         177.3%          2019
# 9                           Singapore             645612         173.5%          2019
# ...

# %%
lista_paises2=Data_2['Country'].tolist()

set(lista_paises2).symmetric_difference(set(lista_paises)).intersection(lista_paises2)
# Out:
# {"Côte d'Ivoire", 'Democratic Republic of the Congo', 'Macao', 'Timor-Leste'}

# %%
'Ivory Coast','DR Congo', 'Macau', 'East Timor'
# Out:
# ('Ivory Coast', 'DR Congo', 'Macau', 'East Timor')

# %%
Data_2['Country']=Data_2['Country'].replace("Côte d'Ivoire",'Ivory Coast')

Data_2['Country']=Data_2['Country'].replace('Democratic Republic of the Congo','DR Congo')
Data_2['Country']=Data_2['Country'].replace('Macao','Macau')
Data_2['Country']=Data_2['Country'].replace("Timor-Leste",'East Timor')

# %%
lista_paises2=Data_2['Country'].tolist()

# %%
len(set(lista_paises2).intersection(set(lista_paises)))
# Out:
# 180

# %%
set(lista_paises2).symmetric_difference(set(lista_paises)).intersection(lista_paises2)
# Out:
# set()

# %%
set(lista_paises2).symmetric_difference(set(lista_paises)).intersection(lista_paises)
# Out:
# {'',
#  'Abkhazia',
#  'American Samoa',
#  'Andorra',
#  'Anguilla',
#  'Barbados',
#  'British Virgin Islands',
#  'Central African Republic',
#  'Chad',
#  'Christmas Island',
#  'Cocos (Keeling) Islands',
#  'Congo',
#  'Cook Islands',
#  'Cuba',
#  'Equatorial Guinea',
#  'Eritrea',
#  'F.S. Micronesia',
#  'Falkland Islands',
#  'Faroe Islands',
#  'French Polynesia',
#  'Gabon',
#  'Gibraltar',
#  'Greenland',
#  'Guam',
#  'Guernsey',
#  'Iran',
#  'Isle of Man',
#  'Jersey',
#  'Liechtenstein',
#  'Monaco',
#  'Montserrat',
#  'New Caledonia',
#  'Niue',
#  'Norfolk Island',
#  'North Korea',
#  'Northern Cyprus',
#  'Northern Mariana Islands',
#  'Pitcairn Islands',
#  'Puerto Rico',
#  'Republic of Artsakh',
#  'Saint Barthélemy',
#  'Saint Helena, Ascensionand Tristan da Cunha',
#  'Saint Pierre and Miquelon',
#  'San Marino',
#  'Sint Maarten',
#  'Somalia',
#  'South Ossetia',
#  'Syria',
#  'Taiwan',
#  'Tokelau',
#  'Transnistria',
#  'Turkmenistan',
#  'Tuvalu',
# ...

# %%
lista_paises2
# Out:
# ['European Union',
#  'China',
#  'United States',
#  'Germany',
#  'Japan',
#  'United Kingdom',
#  'France',
#  'Netherlands',
#  'South Korea',
#  'Hong Kong',
#  'Singapore',
#  'Italy',
#  'Canada',
#  'India',
#  'Ireland',
#  'Mexico',
#  'Spain',
#  'Russia',
#  'Switzerland',
#  'Belgium',
#  'Brazil',
#  'Australia',
#  'Poland',
#  'Thailand',
#  'Saudi Arabia',
#  'Vietnam',
#  'Sweden',
#  'Turkey',
#  'Austria',
#  'Malaysia',
#  'Indonesia',
#  'Denmark',
#  'Czech Republic',
#  'Norway',
#  'Hungary',
#  'Luxembourg',
#  'Israel',
#  'Finland',
#  'South Africa',
#  'Portugal',
#  'Romania',
#  'Slovakia',
#  'Philippines',
#  'Qatar',
#  'Iraq',
#  'Chile',
#  'Kuwait',
#  'Greece',
#  'Argentina',
#  'Nigeria',
#  'Kazakhstan',
#  'Ukraine',
#  'Colombia',
#  'New Zealand',
#  'Peru',
#  'Egypt',
#  'Oman',
#  'Macau',
#  'Slovenia',
#  'Bangladesh',
#  'Morocco',
#  'Bulgaria',
#  'Lithuania',
#  'Belarus',
#  'Algeria',
#  'Angola',
#  'Croatia',
#  'Pakistan',
# ...

# %%
lista_paises
# Out:
# ['',
#  '',
#  'Abkhazia',
#  'Afghanistan',
#  'Albania',
#  'Algeria',
#  'American Samoa',
#  'Andorra',
#  'Angola',
#  'Anguilla',
#  'Antigua and Barbuda',
#  'Argentina',
#  'Armenia',
#  'Aruba',
#  'Australia',
#  'Austria',
#  'Azerbaijan',
#  'Bahamas',
#  'Bahrain',
#  'Bangladesh',
#  'Barbados',
#  'Belarus',
#  'Belgium',
#  'Belize',
#  'Benin',
#  'Bermuda',
#  'Bhutan',
#  'Bolivia',
#  'Bosnia and Herzegovina',
#  'Botswana',
#  'Brazil',
#  'British Virgin Islands',
#  'Brunei',
#  'Bulgaria',
#  'Burkina Faso',
#  'Burundi',
#  'Cambodia',
#  'Cameroon',
#  'Canada',
#  'Cape Verde',
#  'Cayman Islands',
#  'Central African Republic',
#  'Chad',
#  'Chile',
#  'China',
#  'Christmas Island',
#  'Cocos (Keeling) Islands',
#  'Colombia',
#  'Comoros',
#  'Congo',
#  'Cook Islands',
#  'Costa Rica',
#  'Croatia',
#  'Cuba',
#  'Curaçao',
#  'Cyprus',
#  'Czech Republic',
#  'DR Congo',
#  'Denmark',
#  'Djibouti',
#  'Dominica',
#  'Dominican Republic',
# ...

# %%
data_12=pd.merge(Data_1,Data_2, how='outer',on='Country')

# %%
data_12
# Out:
#                                          Country  Population Proporcion_mundial export_million_USD porcentaje_GDP Year_exp_data
# 0                                          China  1407402560              17.9%            2643376          11.8%          2019
# 1                                          India  1375432838              17.5%             530706          18.7%          2019
# 2                                  United States   331458869              4.22%            2498032          11.7%          2019
# 3                                      Indonesia   271350000              3.45%             200100          18.4%          2019
# 4                                       Pakistan   225200000              2.87%              30566          10.1%          2019
# 5                                         Brazil   212969523              2.71%             400541          21.1%          2019
# ...

# %% [markdown]
#
# ## tercer link https://en.wikipedia.org/wiki/List_of_countries_by_imports

# %%
content3 = getHTMLContent('https://en.wikipedia.org/wiki/List_of_countries_by_imports')
tables3 = content3.find_all('table')
for table in tables3:
    print(table.prettify()) #esto es para ver el codigo html y encontrar las tablas que tiene la pagina
# Out:
# <table class="box-Update plainlinks metadata ambox ambox-content ambox-Update" role="presentation">
#  <tbody>
#   <tr>
#    <td class="mbox-image">
#     <div style="width:52px">
#      <img alt="Ambox current red Americas.svg" data-file-height="290" data-file-width="360" decoding="async" height="34" src="//upload.wikimedia.org/wikipedia/commons/thumb/5/53/Ambox_current_red_Americas.svg/42px-Ambox_current_red_Americas.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/5/53/Ambox_current_red_Americas.svg/63px-Ambox_current_red_Americas.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/5/53/Ambox_current_red_Americas.svg/84px-Ambox_current_red_Americas.svg.png 2x" width="42"/>
#     </div>
#    </td>
#    <td class="mbox-text">
#     <div class="mbox-text-span">
#      This article needs to be
#      <b>
#       updated
#      </b>
#      .
#      <span class="hide-when-compact">
# ...

# %%
table3 = content3.find('table', {'class': 'wikitable sortable'}) #esta
rows3 = table3.find_all('tr')
Data_3=pd.DataFrame(columns = ['Country','import_million_USD','Year_imp_data'])
rows_list3=[]

for row in rows3:
    cells3 = row.find_all('td')
    if len(cells3) > 1:
        country= cells3[1].find('a').text
        import_million_USD=cells3[2].text
        
        Year_imp_data=cells3[3].text
        #print(porcentaje_GDP)
        rows_list3.append([country,import_million_USD,Year_imp_data])
Data_3=pd.DataFrame(rows_list3,columns = ['Country','import_million_USD','Year_imp_data'])
Data_3['import_million_USD']=Data_3.apply(lambda x: comma_to_none(x['import_million_USD']),  axis=1) 
Data_3
# Out:
#                                           Country import_million_USD   Year_imp_data
# 0                                   United States          2568396\n          2019\n
# 1                                  European Union          2335303\n       2018[2]\n
# 2                                           China          2068950\n          2019\n
# 3                                         Germany          1236298\n          2019\n
# 4                                           Japan           720964\n          2019\n
# 5                                  United Kingdom           692580\n          2019\n
# 6                                     Netherlands           646752\n          2019\n
# 7                                          France           637949\n          2019\n
# 8                                       Hong Kong           578590\n          2019\n
# 9                                     South Korea           503259\n          2019\n
# ...

# %%
lista_paises3=Data_3['Country'].tolist()

set(lista_paises3).symmetric_difference(set(lista_paises)).intersection(lista_paises3)
# Out:
# {'Bonaire',
#  'British Indian Ocean Territory',
#  'Cocos Islands',
#  "Côte d'Ivoire",
#  'Democratic Republic of the Congo',
#  'European Union',
#  'French Southern and Antarctic Lands',
#  'Macedonia',
#  'Micronesia',
#  'Republic of the Congo',
#  'Saint Helena, Ascension and Tristan da Cunha',
#  'Scotland',
#  'Timor-Leste',
#  'United States Minor Outlying Islands'}

# %%
Data_3['Country']=Data_3['Country'].replace('Cocos Islands','Cocos (Keeling) Islands')
Data_3['Country']=Data_3['Country'].replace("Côte d'Ivoire",'Ivory Coast')

Data_3['Country']=Data_3['Country'].replace('Democratic Republic of the Congo','DR Congo')
#Data_3['Country']=Data_3['Country'].replace('Macao','Macau')

Data_3['Country']=Data_3['Country'].replace('Macedonia','North Macedonia')
Data_3['Country']=Data_3['Country'].replace('Republic of the Congo','Congo')
Data_3['Country']=Data_3['Country'].replace('Saint Helena, Ascension and Tristan da Cunha','Saint Helena, Ascensionand Tristan da Cunha')
Data_3['Country']=Data_3['Country'].replace("Micronesia",'F.S. Micronesia')
Data_3['Country']=Data_3['Country'].replace("Timor-Leste",'East Timor')

# %%
lista_paises3=Data_3['Country'].tolist()

set(lista_paises3).symmetric_difference(set(lista_paises)).intersection(lista_paises3)
# Out:
# {'Bonaire',
#  'British Indian Ocean Territory',
#  'European Union',
#  'French Southern and Antarctic Lands',
#  'Scotland',
#  'United States Minor Outlying Islands'}

# %%
Escocia esta en united kingdom

# %%
lista_paises
# Out:
# ['China',
#  'India',
#  'United States',
#  'Indonesia',
#  'Pakistan',
#  'Brazil',
#  'Nigeria',
#  'Bangladesh',
#  'Russia',
#  'Mexico',
#  'Japan',
#  'Ethiopia',
#  'Philippines',
#  'Egypt',
#  'Vietnam',
#  'DR Congo',
#  'Iran',
#  'Turkey',
#  'Germany',
#  'France',
#  'United Kingdom',
#  'Thailand',
#  'South Africa',
#  'Tanzania',
#  'Italy',
#  'Myanmar',
#  'South Korea',
#  'Colombia',
#  'Kenya',
#  'Spain',
#  'Argentina',
#  'Algeria',
#  'Sudan',
#  'Uganda',
#  'Ukraine',
#  'Iraq',
#  'Canada',
#  'Poland',
#  'Morocco',
#  'Uzbekistan',
#  'Saudi Arabia',
#  'Peru',
#  'Afghanistan',
#  'Malaysia',
#  'Angola',
#  'Ghana',
#  'Mozambique',
#  'Yemen',
#  'Nepal',
#  'Venezuela',
#  'Ivory Coast',
#  'Madagascar',
#  'Australia',
#  'North Korea',
#  'Cameroon',
#  'Niger',
#  'Taiwan',
#  'Sri Lanka',
#  'Burkina Faso',
#  'Mali',
#  'Chile',
#  'Romania',
#  'Kazakhstan',
#  'Malawi',
#  'Zambia',
#  'Syria',
#  'Ecuador',
#  'Netherlands',
#  'Senegal',
# ...

# %%
lista_paises3=Data_3['Country'].tolist()

set(lista_paises3).symmetric_difference(set(lista_paises2)).intersection(lista_paises3)
# Out:
# {'American Samoa',
#  'Andorra',
#  'Anguilla',
#  'Barbados',
#  'Bonaire',
#  'British Indian Ocean Territory',
#  'British Virgin Islands',
#  'Central African Republic',
#  'Chad',
#  'Christmas Island',
#  'Cocos (Keeling) Islands',
#  'Congo',
#  'Cook Islands',
#  'Cuba',
#  'Equatorial Guinea',
#  'Eritrea',
#  'European Union',
#  'F.S. Micronesia',
#  'Falkland Islands',
#  'Faroe Islands',
#  'French Polynesia',
#  'French Southern and Antarctic Lands',
#  'Gabon',
#  'Gibraltar',
#  'Greenland',
#  'Guam',
#  'Iran',
#  'Liechtenstein',
#  'Monaco',
#  'Montserrat',
#  'New Caledonia',
#  'Niue',
#  'Norfolk Island',
#  'North Korea',
#  'Northern Mariana Islands',
#  'Pitcairn Islands',
#  'Puerto Rico',
#  'Saint Helena, Ascensionand Tristan da Cunha',
#  'Saint Pierre and Miquelon',
#  'San Marino',
#  'Scotland',
#  'Sint Maarten',
#  'Somalia',
#  'Syria',
#  'Taiwan',
#  'Tokelau',
#  'Turkmenistan',
#  'Tuvalu',
#  'United Arab Emirates',
# ...

# %%
lista_paises3=Data_3['Country'].tolist()

set(lista_paises3).symmetric_difference(set(lista_paises2)).intersection(lista_paises3)
# Out:
# {'American Samoa',
#  'Andorra',
#  'Anguilla',
#  'Barbados',
#  'Bonaire',
#  'British Indian Ocean Territory',
#  'British Virgin Islands',
#  'Central African Republic',
#  'Chad',
#  'Christmas Island',
#  'Cocos (Keeling) Islands',
#  'Congo',
#  'Cook Islands',
#  'Cuba',
#  'Equatorial Guinea',
#  'Eritrea',
#  'European Union',
#  'F.S. Micronesia',
#  'Falkland Islands',
#  'Faroe Islands',
#  'French Polynesia',
#  'French Southern and Antarctic Lands',
#  'Gabon',
#  'Gibraltar',
#  'Greenland',
#  'Guam',
#  'Iran',
#  'Liechtenstein',
#  'Monaco',
#  'Montserrat',
#  'New Caledonia',
#  'Niue',
#  'Norfolk Island',
#  'North Korea',
#  'Northern Mariana Islands',
#  'Pitcairn Islands',
#  'Puerto Rico',
#  'Saint Helena, Ascensionand Tristan da Cunha',
#  'Saint Pierre and Miquelon',
#  'San Marino',
#  'Scotland',
#  'Sint Maarten',
#  'Somalia',
#  'Syria',
#  'Taiwan',
#  'Tokelau',
#  'Turkmenistan',
#  'Tuvalu',
#  'United Arab Emirates',
# ...

# %%
data_123=pd.merge(data_12,Data_3, how='outer',on='Country')

# %%
data_123
# Out:
#                                          Country  Population Proporcion_mundial export_million_USD porcentaje_GDP Year_exp_data import_million_USD   Year_imp_data
# 0                                          China  1407402560              17.9%            2643376          11.8%          2019          2068950\n          2019\n
# 1                                          India  1375432838              17.5%             530706          18.7%          2019           478883\n          2019\n
# 2                                  United States   331458869              4.22%            2498032          11.7%          2019          2568396\n          2019\n
# 3                                      Indonesia   271350000              3.45%             200100          18.4%          2019           170727\n          2019\n
# 4                                       Pakistan   225200000              2.87%              30566          10.1%          2019            50134\n          2019\n
# ...

# %% [markdown]
# ## Cuarto link https://en.wikipedia.org/wiki/List_of_countries_by_leading_trade_partners

# %%
content4 = getHTMLContent('https://en.wikipedia.org/wiki/List_of_countries_by_leading_trade_partners')
tables4 = content4.find_all('table')
for table in tables4:
    print(table.prettify()) #esto es para ver el codigo html y encontrar las tablas que tiene la pagina
# Out:
# <table class="sidebar sidebar-collapse nomobile">
#  <tbody>
#   <tr>
#    <td class="sidebar-pretitle">
#     <i>
#      Part of
#      <a href="/wiki/Category:Trade" title="Category:Trade">
#       a series
#      </a>
#      on
#     </i>
#    </td>
#   </tr>
#   <tr>
#    <th class="sidebar-title-with-pretitle">
#     <a href="/wiki/International_trade" title="International trade">
#      World trade
#     </a>
#    </th>
#   </tr>
#   <tr>
#    <td class="sidebar-image" style="padding: 0.4em 0 0.4em; border-bottom: 1px solid #ccc">
#     <div class="center">
#      <div class="floatnone">
#       <a class="image" href="/wiki/File:Storck_Harbour_scene.jpg">
# ...

# %%
table4 = content4.find('table', {'class': 'wikitable sortable'}) #esta
rows4 = table4.find_all('tr')
Data_4=pd.DataFrame(columns = ['Country','Leading_Export_Market','Leading_Import_Market'])
rows_list4=[]

for row in rows4:
    cells4 = row.find_all('td')
    if len(cells4) > 1:
        country= cells4[0].find('a').text
        
        try:
            Leading_Export_Market=cells4[1].text
        except:
            Leading_Export_Market=np.nan
        try:    
            Leading_Import_Market=cells4[2].text
        except:
            Leading_Import_Market=np.nan
            
        rows_list4.append([country, Leading_Export_Market,Leading_Import_Market])
Data_4=pd.DataFrame(rows_list4,columns = ['Country','Leading_Export_Market','Leading_Import_Market'])
#Data_4['export_million_USD']=Data_4['export_million_USD'].apply(x:comma_to_none(x) for x in 
Data_4
# Out:
#                                Country Leading_Export_Market    Leading_Import_Market
# 0                          Afghanistan              Pakistan                   Iran\n
# 1                              Albania        European Union         European Union\n
# 2                              Algeria        European Union         European Union\n
# 3                              Andorra                                             \n
# 4                               Angola                 China         European Union\n
# 5                  Antigua and Barbuda         United States          United States\n
# 6                            Argentina                Brazil                 Brazil\n
# 7                              Armenia        European Union                 Russia\n
# 8                            Australia                 China                  China\n
# 9                              Austria        European Union         European Union\n
# ...

# %%
lista_paises4=Data_4['Country'].tolist()

set(lista_paises4).symmetric_difference(set(lista_paises)).intersection(lista_paises4)
# Out:
# {'Bosnia',
#  'Congo, Democratic Republic of the',
#  'European Union',
#  'Federated States of Micronesia',
#  'Sao Tome and Principe',
#  'State of Palestine',
#  'Swaziland',
#  'Timor Leste',
#  'Vatican'}

# %%
#Data_4['Country']=Data_4['Country'].replace('Cocos Islands','Cocos (Keeling) Islands')
#Data_4['Country']=Data_4['Country'].replace("Côte d'Ivoire",'Ivory Coast')

Data_4['Country']=Data_4['Country'].replace('Bosnia','Bosnia and Herzegovina')
Data_4['Country']=Data_4['Country'].replace('Congo, Democratic Republic of the','DR Congo')
Data_4['Country']=Data_4['Country'].replace('Federated States of Micronesia','F.S. Micronesia')
Data_4['Country']=Data_4['Country'].replace('Sao Tome and Principe','São Tomé and Príncipe')
Data_4['Country']=Data_4['Country'].replace('State of Palestine','Palestine')
#Data_4['Country']=Data_4['Country'].replace('Macao','Macau')
Data_4['Country']=Data_4['Country'].replace('Timor Leste','East Timor')

Data_4['Country']=Data_4['Country'].replace('Swaziland','Eswatini')

Data_4['Country']=Data_4['Country'].replace('Vatican','Vatican City')
#Data_4['Country']=Data_4['Country'].replace('Macedonia','North Macedonia')
#Data_4['Country']=Data_4['Country'].replace('Republic of the Congo','Congo')
#Data_4['Country']=Data_4['Country'].replace('Saint Helena, Ascension and Tristan da Cunha','Saint Helena, Ascensionand Tristan da Cunha')

# %%
lista_paises4=Data_4['Country'].tolist()

set(lista_paises4).symmetric_difference(set(lista_paises)).intersection(lista_paises4)
# Out:
# {'European Union'}

# %%
data_1234=pd.merge(data_123,Data_4, how='outer',on='Country')

# %%
data_1234
# Out:
#                                          Country  Population Proporcion_mundial export_million_USD porcentaje_GDP Year_exp_data import_million_USD   Year_imp_data Leading_Export_Market    Leading_Import_Market
# 0                                          China  1407402560              17.9%            2643376          11.8%          2019          2068950\n          2019\n         United States         European Union\n
# 1                                          India  1375432838              17.5%             530706          18.7%          2019           478883\n          2019\n        European Union                  China\n
# 2                                  United States   331458869              4.22%            2498032          11.7%          2019          2568396\n          2019\n        European Union                  China\n
# ...

# %% [markdown]
# ## Quinto link -https://en.wikipedia.org/wiki/List_of_countries_by_oil_exports

# %%
content5 = getHTMLContent('https://en.wikipedia.org/wiki/List_of_countries_by_oil_exports')
tables5 = content5.find_all('table')
for table in tables5:
    print(table.prettify()) #esto es para ver el codigo html y encontrar las tablas que tiene la pagina
# Out:
# <table class="wikitable sortable">
#  <tbody>
#   <tr bgcolor="#ececec">
#    <th>
#     Rank
#    </th>
#    <th>
#     Country/Region
#    </th>
#    <th>
#     Oil - exports
#     <br/>
#     (
#     <a class="mw-redirect" href="/wiki/Barrel_(volume)" title="Barrel (volume)">
#      bbl
#     </a>
#     /day)
#    </th>
#    <th>
#     Date of
#     <br/>
#     information
#    </th>
#   </tr>
#   <tr>
#    <td>
#     1
#    </td>
#    <td>
#     <span class="flagicon">
#      <img alt="" class="thumbborder" data-file-height="600" data-file-width="900" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/0/0d/Flag_of_Saudi_Arabia.svg/23px-Flag_of_Saudi_Arabia.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/0/0d/Flag_of_Saudi_Arabia.svg/35px-Flag_of_Saudi_Arabia.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/0/0d/Flag_of_Saudi_Arabia.svg/45px-Flag_of_Saudi_Arabia.svg.png 2x" width="23"/>
#     </span>
# ...

# %%
table5 = content5.find('table', {'class': 'wikitable sortable'}) #esta
rows5 = table5.find_all('tr')
Data_5=pd.DataFrame(columns = ['Country','oil_export_bbl_day','year_oil_export_data'])
rows_list5=[]

for row in rows5:
    cells5 = row.find_all('td')
    if len(cells5) > 1:
        country= cells5[1].find('a').text
        
        try:
            oil_export_bbl_day=cells5[2].text
        except:
            oil_export_bbl_day=np.nan
        try:    
            year_oil_export_data=cells5[3].text
        except:
            year_oil_export_data=np.nan
            
        rows_list5.append([country, oil_export_bbl_day,year_oil_export_data])
Data_5=pd.DataFrame(rows_list5,columns = ['Country','oil_export_bbl_day','year_oil_export_data'])
#Data_5['export_million_USD']=Data_5['export_million_USD'].apply(x:comma_to_none(x) for x in 
Data_5
# Out:
#                              Country oil_export_bbl_day year_oil_export_data
# 0                       Saudi Arabia         10,600,000          2018 est.\n
# 1                             Russia          5,225,000          2018 est.\n
# 2                               Iraq          3,800,000          2018 est.\n
# 3                      United States          3,770,000               2017\n
# 4                             Canada          3,596,690               2018\n
# 5               United Arab Emirates          2,296,473               2018\n
# 6                             Kuwait          2,050,030               2018\n
# 7                            Nigeria          1,979,451               2018\n
# 8                              Qatar          1,477,213               2018\n
# 9                             Angola          1,420,588               2018\n
# 10                        Kazakhstan          1,292,000           2016 est\n
# ...

# %%
lista_paises5=Data_5['Country'].tolist()

set(lista_paises5).symmetric_difference(set(lista_paises)).intersection(lista_paises5)lista_paises5=Data_5['Country'].tolist()

set(lista_paises5).symmetric_difference(set(lista_paises)).intersection(lista_paises5)
# Out:
# {"Côte d'Ivoire",
#  'Democratic Republic of the Congo',
#  'Republic of the Congo',
#  'Timor-Leste'}

# %%
#Data_5['Country']=Data_5['Country'].replace('Cocos Islands','Cocos (Keeling) Islands')
Data_5['Country']=Data_5['Country'].replace("Côte d'Ivoire",'Ivory Coast')

#Data_5['Country']=Data_5['Country'].replace('Bosnia','Bosnia and Herzegovina')
Data_5['Country']=Data_5['Country'].replace('Democratic Republic of the Congo','DR Congo')
#Data_5['Country']=Data_5['Country'].replace('Federated States of Micronesia','F.S. Micronesia')
#Data_5['Country']=Data_5['Country'].replace('Sao Tome and Principe','São Tomé and Príncipe')
#Data_5['Country']=Data_5['Country'].replace('State of Palestine','Palestine')
#Data_5['Country']=Data_5['Country'].replace('Macao','Macau')
Data_5['Country']=Data_5['Country'].replace('Timor-Leste','East Timor')

#Data_5['Country']=Data_5['Country'].replace('Swaziland','Eswatini')

#Data_5['Country']=Data_5['Country'].replace('Vatican','Vatican City')
#Data_5['Country']=Data_5['Country'].replace('Macedonia','North Macedonia')
Data_5['Country']=Data_5['Country'].replace('Republic of the Congo','Congo')
#Data_5['Country']=Data_5['Country'].replace('Saint Helena, Ascension and Tristan da Cunha','Saint Helena, Ascensionand Tristan da Cunha')

# %%
lista_paises5=Data_5['Country'].tolist()

set(lista_paises5).symmetric_difference(set(lista_paises)).intersection(lista_paises5)
# Out:
# set()

# %%
data_12345=pd.merge(data_1234,Data_5, how='outer',on='Country')

# %%
data_12345
# Out:
#                                          Country  Population Proporcion_mundial export_million_USD porcentaje_GDP Year_exp_data import_million_USD   Year_imp_data Leading_Export_Market    Leading_Import_Market oil_export_bbl_day year_oil_export_data
# 0                                          China  1407402560              17.9%            2643376          11.8%          2019          2068950\n          2019\n         United States         European Union\n             33,000          2013 est.\n
# 1                                          India  1375432838              17.5%             530706          18.7%          2019           478883\n          2019\n        European Union                  China\n                NaN                  NaN
# ...

# %% [markdown]
#  ## Sexto link    -https://en.wikipedia.org/wiki/List_of_countries_by_oil_production

# %%
content6 = getHTMLContent('https://en.wikipedia.org/wiki/List_of_countries_by_oil_production')
tables6 = content6.find_all('table')
for table in tables6:
    print(table.prettify()) #esto es para ver el codigo html y encontrar las tablas que tiene la pagina
# Out:
# <table class="wikitable sortable" style="text-align:right">
#  <tbody>
#   <tr>
#    <th>
#     Rank
#    </th>
#    <th>
#     Country
#    </th>
#    <th>
#     Oil production
#     <br/>
#     <small>
#      2020 (
#      <a href="/wiki/Barrel_(unit)#Oil_barrel" title="Barrel (unit)">
#       bbl
#      </a>
#      /day)
#     </small>
#     <sup class="reference" id="cite_ref-EIA_1-1">
#      <a href="#cite_note-EIA-1">
#       [1]
#      </a>
#     </sup>
#    </th>
#    <th>
#     Oil production per capita
#     <br/>
#     <small>
#      2017 (
#      <a href="/wiki/Barrel_(unit)#Oil_barrel" title="Barrel (unit)">
#       bbl
#      </a>
#      /day/million people)
#      <sup class="reference" id="cite_ref-UN_6-1">
#       <a href="#cite_note-UN-6">
#        [6]
#       </a>
#      </sup>
#     </small>
#    </th>
#   </tr>
#   <tr>
#    <td>
#     1
#    </td>
#    <td align="left">
#     <span class="flagicon">
# ...

# %%
table6 = content6.find('table', {'class': 'wikitable sortable'}) #esta
rows6 = table6.find_all('tr')

# %%
ad=rows6[82].find_all('td')

# %%
ad[1].find('a')
# Out:
# <a href="/wiki/Czech_Republic" title="Czech Republic">Czechia</a>

# %%
for row in rows6:
    cells6 = row.find_all('td')
    if len(cells6) > 1:
        try:
            country= cells6[1].find('a').text
            oil_production_bbl_day=cells6[2].text
            oil_production_bbl_day_per_capita=cells6[3].text
        except:
           
            country= cells6[0].find('a').text
            oil_production_bbl_day=cells6[1].text
            oil_production_bbl_day_per_capita=cells6[2].text
        
            
        #print(oil_production_bbl_day)
# Out:
# 11,307,560
# 9,865,495
# 9,264,921
# 4,201,101
# 4,102,311
# 3,888,989
# 3,138,249
# 2,939,950
# 2,665,809
# 2,625,145
# 1,775,940
# 1,756,705
# 1,712,937
# 1,710,303
# 1,530,000
# 1,249,678
# 1,122,432
# 948,967
# 947,208
# 791,844
# 712,112
# 693,880
# 627,415
# 586,735
# 541,017
# 527,063
# 479,371
# 440,335
# 408,074
# 351,180
# 282,541
# 202,117
# 199,478
# 193,264
# 184,579
# 173,634
# 162,475
# 147,563
# 115,817
# 100,514
# 98,642
# 83,174
# 79,112
# 71,339
# 67,574
# 66,749
# 66,000
# 64,740
# 61,757
# 60,161
# 56,556
# 43,000
# 41,079
# 40,386
# 40,249
# 37,997
# 37,508
# 36,746
# 35,000
# 34,249
# 33,577
# 30,738
# 23,000
# 18,765
# 18,579
# 17,582
# 16,418
# 15,249
# 14,915
# 14,579
# 14,331
# 14,000
# 12,910
# 12,249
# 11,749
# 10,822
# 9,497
# 8,833
# 7,749
# 4,333
# 3,000
# 2,000
# 2,000
# 1,831
# 1,700
# 1,582
# 1,000
# 1,000
# 1,000
# 1,000
# 628
# 400
# 300
# 200
# 196
# 180
# 160

# %%
table6 = content6.find('table', {'class': 'wikitable sortable'}) #esta
rows6 = table6.find_all('tr')
Data_6=pd.DataFrame(columns = ['Country','oil_production_bbl_day','oil_production_bbl_day_per_capita'])
rows_list6=[]

for row in rows6:
    cells6 = row.find_all('td')
    if len(cells6) > 1:
        try:
            country= cells6[1].find('a').text
            oil_production_bbl_day=cells6[2].text
            oil_production_bbl_day_per_capita=cells6[3].text
        except:
           
            country= cells6[0].find('a').text
            oil_production_bbl_day=cells6[1].text
            oil_production_bbl_day_per_capita=cells6[2].text
            
        rows_list6.append([country, oil_production_bbl_day,oil_production_bbl_day_per_capita])
Data_6=pd.DataFrame(rows_list6,columns = ['Country','oil_production_bbl_day','oil_production_bbl_day_per_capita'])
#Data_6['export_million_USD']=Data_6['export_million_USD'].apply(x:comma_to_none(x) for x in 
Data_6
# Out:
#                  Country oil_production_bbl_day oil_production_bbl_day_per_capita
# 0          United States             11,307,560                          35,922\n
# 1                 Russia              9,865,495                          73,292\n
# 2           Saudi Arabia              9,264,921                         324,866\n
# 3                 Canada              4,201,101                         100,931\n
# 4                   Iraq              4,102,311                         119,664\n
# 5                  China              3,888,989                           2,836\n
# 6   United Arab Emirates              3,138,249                         335,103\n
# 7                 Brazil              2,939,950                          12,113\n
# 8                   Iran              2,665,809                          49,714\n
# 9                 Kuwait              2,625,145                         721,575\n
# ...

# %%
lista_paises6=Data_6['Country'].tolist()

set(lista_paises6).symmetric_difference(set(lista_paises)).intersection(lista_paises6)
# Out:
# {'Congo-Brazzaville',
#  'Congo-Kinshasa',
#  'Czechia',
#  "Côte d'Ivoire",
#  'Republic of China'}

# %%
#Data_6['Country']=Data_6['Country'].replace('Cocos Islands','Cocos (Keeling) Islands')
Data_6['Country']=Data_6['Country'].replace("Côte d'Ivoire",'Ivory Coast')

#Data_6['Country']=Data_6['Country'].replace('Bosnia','Bosnia and Herzegovina')
Data_6['Country']=Data_6['Country'].replace('Czechia','Czech Republic')
Data_6['Country']=Data_6['Country'].replace('Congo-Kinshasa','DR Congo')
#Data_6['Country']=Data_6['Country'].replace('Federated States of Micronesia','F.S. Micronesia')
#Data_6['Country']=Data_6['Country'].replace('Sao Tome and Principe','São Tomé and Príncipe')
#Data_6['Country']=Data_6['Country'].replace('State of Palestine','Palestine')
#Data_6['Country']=Data_6['Country'].replace('Macao','Macau')
#Data_6['Country']=Data_6['Country'].replace('Timor-Leste','East Timor')

#Data_6['Country']=Data_6['Country'].replace('Swaziland','Eswatini')

#Data_6['Country']=Data_6['Country'].replace('Vatican','Vatican City')
#Data_6['Country']=Data_6['Country'].replace('Macedonia','North Macedonia')
Data_6['Country']=Data_6['Country'].replace('Congo-Brazzaville','Congo')
#Data_6['Country']=Data_6['Country'].replace('Saint Helena, Ascension and Tristan da Cunha','Saint Helena, Ascensionand Tristan da Cunha')
Data_6['Country']=Data_6['Country'].replace("Republic of China",'China')

# %%
lista_paises6=Data_6['Country'].tolist()

set(lista_paises6).symmetric_difference(set(lista_paises)).intersection(lista_paises6)
# Out:
# set()

# %%
data_123456=pd.merge(data_12345,Data_6, how='outer',on='Country')

# %%
data_123456
# Out:
#                                          Country  Population Proporcion_mundial export_million_USD porcentaje_GDP Year_exp_data import_million_USD   Year_imp_data Leading_Export_Market    Leading_Import_Market oil_export_bbl_day year_oil_export_data oil_production_bbl_day oil_production_bbl_day_per_capita
# 0                                          China  1407402560              17.9%            2643376          11.8%          2019          2068950\n          2019\n         United States         European Union\n             33,000          2013 est.\n              3,888,989                           2,836\n
# 1                                          China  1407402560              17.9%            2643376          11.8%          2019          2068950\n          2019\n         United States         European Union\n             33,000          2013 est.\n                    196                               8\n
# ...

# %%
data_123456.to_csv('Country_Trade_GDP.csv', index=False)

# %%
# EL septimo no va

# %% [markdown]
# ## septimo link https://en.wikipedia.org/wiki/List_of_countries_by_net_oil_exports

# %%
content7 = getHTMLContent('https://en.wikipedia.org/wiki/List_of_countries_by_net_oil_exports')
tables7 = content7.find_all('table')
for table in tables7:
    print(table.prettify()) #esto es para ver el codigo html y encontrar las tablas que tiene la pagina
# Out:
# <table class="wikitable sortable" style="text-align:right">
#  <tbody>
#   <tr>
#    <th>
#     Rank
#    </th>
#    <th>
#     Country
#    </th>
#    <th>
#     Exports in barrels/day
#    </th>
#    <th>
#     Year
#    </th>
#    <th>
#     Imports
#    </th>
#    <th>
#     Year
#    </th>
#    <th>
#     Net exports
#    </th>
#    <th>
#     Domestic production, 2016
#     <sup class="reference" id="cite_ref-EIA_3-0">
#      <a href="#cite_note-EIA-3">
#       [3]
#      </a>
#     </sup>
#    </th>
#   </tr>
#   <tr>
#    <td>
#     1
#    </td>
#    <td align="left">
#     <span class="flagicon">
# ...

# %%
table7 = content7.find('table', {'class': 'wikitable sortable'}) #esta
rows7 = table7.find_all('tr')
Data_7=pd.DataFrame(columns = ['Country','oil_production_bbl_day','oil_production_bbl_day_per_capita'])
rows_list7=[]

for row in rows7:
    cells7 = row.find_all('td')
    if len(cells7) > 1:
        try:
            country= cells7[1].find('a').text
            oil_production_bbl_day=cells7[2].text
            oil_production_bbl_day_per_capita=cells7[3].text
        except:
           
            country= cells7[0].find('a').text
            oil_production_bbl_day=cells7[1].text
            oil_production_bbl_day_per_capita=cells7[2].text
            
        rows_list7.append([country, oil_production_bbl_day,oil_production_bbl_day_per_capita])
Data_7=pd.DataFrame(rows_list7,columns = ['Country','oil_production_bbl_day','oil_production_bbl_day_per_capita'])
#Data_7['export_million_USD']=Data_7['export_million_USD'].apply(x:comma_to_none(x) for x in 
Data_7

# %% [markdown]
# ## Unir data set de 1 a 6 formando un csv

# %%
import numpy as np
import pandas as pd

from urllib.request import urlopen
from bs4 import BeautifulSoup









#Funcion que trae el contenido de un url con BeautifulSoup
def getHTMLContent(link):
    html = urlopen(link)
    soup = BeautifulSoup(html, 'html.parser')
    return soup


#funcion auxiliar que quita las comas de un string
def comma_to_none(string):
    '''numero con comas en la escritura se las quito para que quede con formato numerico'''
    string_list = string.split(',')
    new_string = ''.join(string_list[:])
    return new_string 

## Primer link https://en.wikipedia.org/wiki/List_of_countries_and_dependencies_by_population

#esta celda es para saber como encontrar la tabla en el html

content = getHTMLContent('https://en.wikipedia.org/wiki/List_of_countries_and_dependencies_by_population')

#encontre que la etiqueta que necesito es wikitable sortable plainrowheaders

table = content.find('table', {'class': 'wikitable sortable plainrowheaders'})
rows = table.find_all('tr')

# Me armo el primer data frame con country y population del primer link








rows_list=[]


# 
for row in rows:
    cells = row.find_all('td')
    if len(cells) > 1:
        country = cells[0].find('a').text
        population=cells[1].text
        proporcion=cells[2].text
        
        
        rows_list.append([country,population,proporcion])
Data_1=pd.DataFrame(rows_list,columns = ['Country','Population','_%_world'])
Data_1['Population']=Data_1.apply(lambda x: comma_to_none(x['Population']),  axis=1)

#Agrego Palestina a mano parece q como to ma el link
Data_1['Country'][120]='Palestine'





lista_paises=Data_1['Country'].tolist()











## Segundo Link https://en.wikipedia.org/wiki/List_of_countries_by_exports

content2 = getHTMLContent('https://en.wikipedia.org/wiki/List_of_countries_by_exports')


table2 = content2.find('table', {'class': 'wikitable sortable'})
rows2 = table2.find_all('tr')

Data_2=pd.DataFrame(columns = ['Country','export_million_USD','_%_GDP','Year_exp_data'])
rows_list2=[]

for row in rows2:
    cells2 = row.find_all('td')
    if len(cells2) > 1:
        country= cells2[1].find('a').text
        export_million_USD=cells2[2].text
        porcentaje_GDP=cells2[3].text
        Year_exp_data=cells2[4].text[:-1]
        #print(porcentaje_GDP)
        rows_list2.append([country,export_million_USD,porcentaje_GDP,Year_exp_data])
Data_2=pd.DataFrame(rows_list2,columns = ['Country','export_million_USD','_%_GDP','Year_exp_data'])
Data_2['export_million_USD']=Data_2.apply(lambda x: comma_to_none(x['export_million_USD']),  axis=1)
    



Data_2['Country']=Data_2['Country'].replace("Côte d'Ivoire",'Ivory Coast')

Data_2['Country']=Data_2['Country'].replace('Democratic Republic of the Congo','DR Congo')
Data_2['Country']=Data_2['Country'].replace('Macao','Macau')
Data_2['Country']=Data_2['Country'].replace("Timor-Leste",'East Timor')



data_12=pd.merge(Data_1,Data_2, how='outer',on='Country')

data_12







 
## tercer link https://en.wikipedia.org/wiki/List_of_countries_by_imports

content3 = getHTMLContent('https://en.wikipedia.org/wiki/List_of_countries_by_imports')

table3 = content3.find('table', {'class': 'wikitable sortable'}) #esta
rows3 = table3.find_all('tr')
Data_3=pd.DataFrame(columns = ['Country','import_million_USD','Year_imp_data'])
rows_list3=[]

for row in rows3:
    cells3 = row.find_all('td')
    if len(cells3) > 1:
        country= cells3[1].find('a').text
        import_million_USD=cells3[2].text
        
        Year_imp_data=cells3[3].text
        #print(porcentaje_GDP)
        rows_list3.append([country,import_million_USD,Year_imp_data])
Data_3=pd.DataFrame(rows_list3,columns = ['Country','import_million_USD','Year_imp_data'])
Data_3['import_million_USD']=Data_3.apply(lambda x: comma_to_none(x['import_million_USD']),  axis=1) 




Data_3['Country']=Data_3['Country'].replace('Cocos Islands','Cocos (Keeling) Islands')
Data_3['Country']=Data_3['Country'].replace("Côte d'Ivoire",'Ivory Coast')

Data_3['Country']=Data_3['Country'].replace('Democratic Republic of the Congo','DR Congo')
#Data_3['Country']=Data_3['Country'].replace('Macao','Macau')

Data_3['Country']=Data_3['Country'].replace('Macedonia','North Macedonia')
Data_3['Country']=Data_3['Country'].replace('Republic of the Congo','Congo')
Data_3['Country']=Data_3['Country'].replace('Saint Helena, Ascension and Tristan da Cunha','Saint Helena, Ascensionand Tristan da Cunha')
Data_3['Country']=Data_3['Country'].replace("Micronesia",'F.S. Micronesia')
Data_3['Country']=Data_3['Country'].replace("Timor-Leste",'East Timor')


data_123=pd.merge(data_12,Data_3, how='outer',on='Country')










## Cuarto link https://en.wikipedia.org/wiki/List_of_countries_by_leading_trade_partners

content4 = getHTMLContent('https://en.wikipedia.org/wiki/List_of_countries_by_leading_trade_partners')





table4 = content4.find('table', {'class': 'wikitable sortable'}) #esta
rows4 = table4.find_all('tr')
Data_4=pd.DataFrame(columns = ['Country','Leading_Export_Market','Leading_Import_Market'])
rows_list4=[]

for row in rows4:
    cells4 = row.find_all('td')
    if len(cells4) > 1:
        country= cells4[0].find('a').text
        
        try:
            Leading_Export_Market=cells4[1].text
        except:
            Leading_Export_Market=np.nan
        try:    
            Leading_Import_Market=cells4[2].text
        except:
            Leading_Import_Market=np.nan
            
        rows_list4.append([country, Leading_Export_Market,Leading_Import_Market])
Data_4=pd.DataFrame(rows_list4,columns = ['Country','Leading_Export_Market','Leading_Import_Market'])

Data_4['Country']=Data_4['Country'].replace('Bosnia','Bosnia and Herzegovina')
Data_4['Country']=Data_4['Country'].replace('Congo, Democratic Republic of the','DR Congo')
Data_4['Country']=Data_4['Country'].replace('Federated States of Micronesia','F.S. Micronesia')
Data_4['Country']=Data_4['Country'].replace('Sao Tome and Principe','São Tomé and Príncipe')
Data_4['Country']=Data_4['Country'].replace('State of Palestine','Palestine')
#Data_4['Country']=Data_4['Country'].replace('Macao','Macau')
Data_4['Country']=Data_4['Country'].replace('Timor Leste','East Timor')

Data_4['Country']=Data_4['Country'].replace('Swaziland','Eswatini')

Data_4['Country']=Data_4['Country'].replace('Vatican','Vatican City')


data_1234=pd.merge(data_123,Data_4, how='outer',on='Country')





## Quinto link -https://en.wikipedia.org/wiki/List_of_countries_by_oil_exports


content5 = getHTMLContent('https://en.wikipedia.org/wiki/List_of_countries_by_oil_exports')

table5 = content5.find('table', {'class': 'wikitable sortable'}) #esta
rows5 = table5.find_all('tr')
Data_5=pd.DataFrame(columns = ['Country','oil_export_bbl_day','year_oil_export_data'])
rows_list5=[]

for row in rows5:
    cells5 = row.find_all('td')
    if len(cells5) > 1:
        country= cells5[1].find('a').text
        
        try:
            oil_export_bbl_day=cells5[2].text
        except:
            oil_export_bbl_day=np.nan
        try:    
            year_oil_export_data=cells5[3].text
        except:
            year_oil_export_data=np.nan
            
        rows_list5.append([country, oil_export_bbl_day,year_oil_export_data])
Data_5=pd.DataFrame(rows_list5,columns = ['Country','oil_export_bbl_day','year_oil_export_data'])



#Data_5['Country']=Data_5['Country'].replace('Cocos Islands','Cocos (Keeling) Islands')
Data_5['Country']=Data_5['Country'].replace("Côte d'Ivoire",'Ivory Coast')

#Data_5['Country']=Data_5['Country'].replace('Bosnia','Bosnia and Herzegovina')
Data_5['Country']=Data_5['Country'].replace('Democratic Republic of the Congo','DR Congo')

Data_5['Country']=Data_5['Country'].replace('Timor-Leste','East Timor')

#Data_5['Country']=Data_5['Country'].replace('Swaziland','Eswatini')

#Data_5['Country']=Data_5['Country'].replace('Vatican','Vatican City')
#Data_5['Country']=Data_5['Country'].replace('Macedonia','North Macedonia')
Data_5['Country']=Data_5['Country'].replace('Republic of the Congo','Congo')
#Data_5['Country']=Data_5['Country'].replace('Saint Helena, Ascension and Tristan da Cunha','Saint Helena, Ascensionand Tristan da Cunha')




data_12345=pd.merge(data_1234,Data_5, how='outer',on='Country')

data_12345






 ## Sexto link    -https://en.wikipedia.org/wiki/List_of_countries_by_oil_production

content6 = getHTMLContent('https://en.wikipedia.org/wiki/List_of_countries_by_oil_production')





table6 = content6.find('table', {'class': 'wikitable sortable'}) #esta
rows6 = table6.find_all('tr')
Data_6=pd.DataFrame(columns = ['Country','oil_production_bbl_day','oil_production_bbl_day_per_capita'])
rows_list6=[]

for row in rows6:
    cells6 = row.find_all('td')
    if len(cells6) > 1:
        try:
            country= cells6[1].find('a').text
            oil_production_bbl_day=cells6[2].text
            oil_production_bbl_day_per_capita=cells6[3].text
        except:
           
            country= cells6[0].find('a').text
            oil_production_bbl_day=cells6[1].text
            oil_production_bbl_day_per_capita=cells6[2].text
            
        rows_list6.append([country, oil_production_bbl_day,oil_production_bbl_day_per_capita])
        
Data_6=pd.DataFrame(rows_list6,columns = ['Country','oil_production_bbl_day','oil_production_bbl_day_per_capita'])

Data_6['Country']=Data_6['Country'].replace("Côte d'Ivoire",'Ivory Coast')

#Data_6['Country']=Data_6['Country'].replace('Bosnia','Bosnia and Herzegovina')
Data_6['Country']=Data_6['Country'].replace('Czechia','Czech Republic')
Data_6['Country']=Data_6['Country'].replace('Congo-Kinshasa','DR Congo')

Data_6['Country']=Data_6['Country'].replace('Congo-Brazzaville','Congo')
#Data_6['Country']=Data_6['Country'].replace('Saint Helena, Ascension and Tristan da Cunha','Saint Helena, Ascensionand Tristan da Cunha')





data_123456=pd.merge(data_12345,Data_6, how='outer',on='Country')



data_123456.to_csv('Country_Trade_GDP2.csv', index=False)

# EL septimo no va

## septimo link https://en.wikipedia.org/wiki/List_of_countries_by_net_oil_exports

# %%
dataprobada=pd.read_csv('Country_Trade_GDP2.csv')

# %%
dataprobada.head(3)
# Out:
#          Country    Population _%_world  export_million_USD _%_GDP  \
# 0          China  1.407461e+09    17.9%           2643376.0  11.8%
# 1          India  1.375594e+09    17.5%            530706.0  18.7%
# 2  United States  3.314814e+08    4.22%           2498032.0  11.7%
#
#    Year_exp_data  import_million_USD Year_imp_data Leading_Export_Market  \
# 0         2019.0           2068950.0        2019\n         United States
# 1         2019.0            478883.0        2019\n        European Union
# 2         2019.0           2568396.0        2019\n        European Union
#
#   Leading_Import_Market oil_export_bbl_day year_oil_export_data  \
# 0      European Union\n             33,000          2013 est.\n
# 1               China\n                NaN                  NaN
# 2               China\n          3,770,000               2017\n
#
#   oil_production_bbl_day oil_production_bbl_day_per_capita
# 0              3,888,989                           2,836\n
# ...
